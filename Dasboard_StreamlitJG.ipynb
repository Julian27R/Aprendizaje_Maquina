# %% [markdown]
# <a href="https://colab.research.google.com/github/Julian27R/Aprendizaje_Maquina/blob/main/Dasboard_StreamlitJG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Descarga y carga automática de archivos .npy desde Google Drive**

# %%
# 1. IMPORTAR LIBRERÍAS
import gdown
import numpy as np

# 2. DESCARGA DESDE GOOGLE DRIVE
# Reemplaza los FILE_IDs con los de tus archivos en Google Drive
files = {
    "ytest.npy": "1oVI30y_-R419sRFOyQRMm4kxjg9Jq-7k",       # ID de ytest.npy
    "y_pred_RF.npy": "1v73XOtzc22ibTcj-XrwdEGHNdD4MGWEl",    # ID de y_pred_RF.npy
    "y_pred_LR.npy": "1-pxpLmMgEGx95E4HzMRqT-y6W0gbHtbe",    # ID de y_pred_BR.npy
    "y_pred_Elastic.npy": "1xFLZHPvRXGecqjmy9tI6LQp1HReTdP2E"     # ID de y_pred_EN.npy
}

for filename, file_id in files.items():
    url = f"https://drive.google.com/uc?id={file_id}"
    print(f"Descargando {filename}...")
    gdown.download(url, filename, quiet=False)

# 3. CARGA DE ARCHIVOS .NPY
ytest = np.load("ytest.npy")
y_pred_RF = np.load("y_pred_RF.npy")
y_pred_LR = np.load("y_pred_LR.npy")
y_pred_Elastic = np.load("y_pred_Elastic.npy")

print("Todos los archivos se han descargado y cargado correctamente.")
# Out:
# Descargando ytest.npy...
# Downloading...
# From: https://drive.google.com/uc?id=1oVI30y_-R419sRFOyQRMm4kxjg9Jq-7k
# To: /content/ytest.npy
# 100%|██████████| 7.16k/7.16k [00:00<00:00, 12.3MB/s]
# Descargando y_pred_RF.npy...
# Downloading...
# From: https://drive.google.com/uc?id=1v73XOtzc22ibTcj-XrwdEGHNdD4MGWEl
# To: /content/y_pred_RF.npy
# 100%|██████████| 7.16k/7.16k [00:00<00:00, 12.8MB/s]
# Descargando y_pred_LR.npy...
# Downloading...
# From: https://drive.google.com/uc?id=1-pxpLmMgEGx95E4HzMRqT-y6W0gbHtbe
# To: /content/y_pred_LR.npy
# 100%|██████████| 7.16k/7.16k [00:00<00:00, 9.62MB/s]
# Descargando y_pred_Elastic.npy...
# Downloading...
# From: https://drive.google.com/uc?id=1xFLZHPvRXGecqjmy9tI6LQp1HReTdP2E
# To: /content/y_pred_Elastic.npy
# 100%|██████████| 7.16k/7.16k [00:00<00:00, 11.4MB/s]
# Todos los archivos se han descargado y cargado correctamente.

# %% [markdown]
# #**Instalación de streamlit**

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.4)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.13.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.39.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 56.4 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.8 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.45.1 watchdog-6.0.0

# %% [markdown]
# #**Instalar LocalTunnel para exponer el dashboard de Streamlit**

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋
# added 22 packages in 3s
# ⠋
# ⠋3 packages are looking for funding
# ⠋  run `npm fund` for details
# ⠋

# %% [markdown]
# #**Crear archivo dashboard_regresion.py para visualización con Streamlit**
#
# ##Prompt:
# Crea un dashboard en Streamlit para comparar tres modelos de regresión (RandomForest, LinearRegression y ElasticNet) que cargue las predicciones desde archivos .npy (ytest.npy, y_pred_RF.npy, y_pred_LR.npy, y_pred_Elastic.npy). El dashboard debe incluir: (1) una tabla comparativa de métricas (MAE, MSE, R², MAPE) con highlight de los mejores valores, (2) gráficos interactivos de barras para comparar métricas seleccionables, (3) scatter plots de predicciones vs valores reales con línea de referencia, (4) visualización de hiperparámetros óptimos por modelo, y (5) un sidebar con opciones. Usa Streamlit, Plotly y Matplotlib, con diseño responsive y estilo profesional. Guarda el código en dashboard_regresion.py con %%writefile.

# %%
# %%writefile dashboard_regresion.py
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# Cargar predicciones y ytest desde archivos .npy
ytest = np.load("ytest.npy")
y_pred_RF = np.load("y_pred_RF.npy")
y_pred_LR = np.load("y_pred_LR.npy")
y_pred_Elastic = np.load("y_pred_Elastic.npy")

# Configuración de la página
st.set_page_config(page_title="Análisis de Modelos de Regresión", layout="wide")
st.title("Dashboard Comparativo: Modelos de Regresión")

metrics = {
    "RandomForest": {"MAE": 14760.234328, "MSE": 592653976.753763, "R2": 0.915690, "MAPE": 0.084261},
    "LinearRegression": {"MAE": 19484.6592, "MSE": 924179698.9278, "R2": 0.8685, "MAPE": 0.1117},
    "ElasticNet": {"MAE": 19485.507914, "MSE": 924241771.691379, "R2": 0.868518, "MAPE": 0.111726}
}

# --- Página Principal ---
st.header("Resumen Comparativo")
df_metrics = pd.DataFrame(metrics).T
st.dataframe(df_metrics.style.highlight_min(axis=0), height=200)

# Gráfico de métricas comparativas
metric_option = st.selectbox("Selecciona una métrica para comparar:", ["MAE", "MSE", "R2", "MAPE"])
fig = px.bar(df_metrics, y=metric_option, title=f"Comparación de {metric_option} entre Modelos")
st.plotly_chart(fig, use_container_width=True)

# --- Pestañas por Modelo ---
tab1, tab2, tab3 = st.tabs(["RandomForest", "Linear Regresor", "ElasticNet"])

with tab1:
    st.header("RandomForest")
    col1, col2 = st.columns(2)
    with col1:
        st.subheader("Mejores Hiperparámetros")
        st.json({
            "n_estimators": 109,
            "max_depth": 25,
            "min_samples_split": 2,
            "min_samples_leaf": 1,
            "max_features": "None"
        })
    with col2:
        st.subheader("Métricas")
        st.write(df_metrics.loc["RandomForest"].to_frame().T)

    fig, ax = plt.subplots()
    ax.scatter(ytest, y_pred_RF, alpha=0.5)
    ax.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], 'r--')
    ax.set_title("Predicciones vs Valores Reales (RandomForest)")
    ax.set_xlabel("Valores Reales")
    ax.set_ylabel("Valores Predichos")
    st.pyplot(fig)

with tab2:
    st.header("📈 Linear Regression")
    st.subheader("Métricas")
    st.write(df_metrics.loc["LinearRegression"].to_frame().T)

    # Residual plot (simulado)
    fig, ax = plt.subplots()
    ax.scatter(ytest, y_pred_LR, alpha=0.5)
    ax.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], 'r--')
    ax.set_title("Valores Reales vs Valores Predichos")
    ax.set_xlabel("Valores Reales")
    ax.set_ylabel("Valores Predichos")
    st.pyplot(fig)

with tab3:
    st.header("ElasticNet")
    col1, col2 = st.columns(2)
    with col1:
        st.subheader("Mejores Parámetros")
        st.json({
            "alpha": 0.0001,
            "l1_ratio": 0.9
        })
    with col2:
        st.subheader("Métricas")
        st.write(df_metrics.loc["ElasticNet"].to_frame().T)

    fig, ax = plt.subplots()
    ax.scatter(ytest, y_pred_Elastic, alpha=0.5)
    ax.plot([ytest.min(), ytest.max()], [ytest.min(), ytest.max()], 'r--')
    ax.set_title("Predicciones vs Valores Reales (ElasticNet)")
    ax.set_xlabel("Valores Reales")
    ax.set_ylabel("Valores Predichos")
    st.pyplot(fig)

# --- Sidebar ---
with st.sidebar:
    st.header("Opciones")
    show_code = st.checkbox("Mostrar código del dashboard")
    if show_code:
        st.code("""
        # Código disponible en GitHub:
        # https://github.com/Julian27R/Aprendizaje_Maquina/tree/main/PARCIAL_1
        """)

st.markdown("---")
st.caption("Dashboard creado por Julian Gutierrez R | Datos actualizados: 2025")
# Out:
# Overwriting dashboard_regresion.py

# %% [markdown]
# #**Obtener Contraseña del Túnel (IP Pública) para Localtunnel**

# %%
# !curl ifconfig.me
# Out:
# 34.125.226.2

# %% [markdown]
# #**Lanzar Aplicación Streamlit en Background y Crear Túnel Público con Localtunnel**

# %%
import threading
import time
import os

# Ejecutar Streamlit en segundo plano
def run_streamlit():
    os.system('streamlit run dashboard_regresion.py')

thread = threading.Thread(target=run_streamlit)
thread.start()

# Esperar a que Streamlit levante el servidor
time.sleep(5)

# Crear túnel con localtunnel
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦your url is: https://sixty-needles-melt.loca.lt
# ^C
